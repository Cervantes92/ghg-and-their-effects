# %% [markdown]
# <h1>The Corelation between Carbon Dioxide, Radiative Forcing, and Mean Annual Temperature:</h1>
# <p>We wish to explore the relationship between global temperatures and concentrations of greenhouse gases. To accomplish this, wWe have three sets of data: the mean annual temperature data between the years 1880-2018, direct atmospheric CO2 measurements for the years 1959-2017 and the calculated global radiative forcing for CO2 and other prominent greenhouse gases.</p>
#
# <h3>Mean Annual Temperature Anomalies</h3>
# <p>The mean annual temperature anomalies are measured as local mean deviations of the local average temperatures for numerous stations all over the world over the years 1951-1980, this allows the measurement to be reasonably temperature independant, making it an ideal metric for global temperature. I acquired this data from the National Aeronautics and Space Administration's (NASA) webpage. The experiment itself was carried out by Goddard Institute for Space Studies.</p>
# <p>
# https://data.giss.nasa.gov/gistemp/
# </p>
#
# <h3>Annual Greenhouse Gas Index</h3>
# <p>The annual greenhouse gas index (AGGI) is the calculated radiative forcing (how much thermal energy is being 'trapped' per square meter surface). Calculations of the radiative forcing are based off of the concentration of various greenhouse gases including CO2 (carbon dioxide), CH4 (methane), N2O (nitrous oxide) et al. Thus, there will be known corelation between the calculated radiative forcing and the concenctration of carbon dioxide in the atmosphere. This data is useful because it encompases the effects of other known greenhouse gasses.</p>
# <p>
# https://www.esrl.noaa.gov/gmd/aggi/aggi.html
# </p>
#
# <h3>Atmospheric Carbon Dioxide</h3>
# <p>The atmospheric carbon dioxide in ppm is a measure of the concentration of the carbon dioxide in the atmosphere. The data used here was collected from the Mauna Loa Observatory in Hawaii. Mauna Loa constitutes the longest record of direct atmospheric carbon dioxide measurements. I would like to introduce more data sources for the atmospheric concentration of carbon dioxide in the atmosphere as there are numerous probes all over the globe (see AGGI citation), but given the relative remoteness and elevation of the Mauna Loa observatory, measurements of the carbon dioxide should be more than reliable and accurate for our purposes.</p>
# <p>
# https://www.esrl.noaa.gov/gmd/ccgg/trends/full.html
# </p>
#
# <h2>A Note on Bias:</h2>
# <p>Climate science, particularly when it comes to climate change, is often a highly politicized field of study. Thus, it is important to be cautious of selecting data that only confirms one's innate bias of the subject. Much of my time in this project was spent reading up on the data collection methodologies used by NASA and NOAA to make note of the underlying rational of the data, and to critically considder if this data is useful in my corelative analysis.</p>
#
# <h2>The Data</h2>
# <p>To begin, let us take a look at the data we are interested in studying. We begin by parsing the data into dataframes as below. To make the data easier to work with, we also set the index of each dataset to be the year each measurement was taken.</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from scipy import stats
# %matplotlib inline

#Annual Greenhouse Gas Index
#Global Radiative Forcing 1980 - 2017 (W m-2)
aggi = pd.read_csv('noaa/AGGI_Table-1.csv').set_index('Year')
#aggi.set_index('Year')

#Atmospheric CO2 in PPM 1959-2017
co2ppm = pd.read_csv('datahub/co2-annmean-mlo_csv.csv').set_index('Year')
#co2ppm.set_index('Year')

#Global Mean Land-Sea Temperature 1880-2018
temp = pd.read_csv('nasa/GLB.Ts+dSST-1.csv').set_index('Year')
#temp.set_index('Year')

# %%
plt.figure(figsize = (10,12))

#Plot of Total 
plt.subplot(3,1,1)
plt.plot(aggi['Total RF'])
plt.title('Annual Greenhouse Gas Index 1980-2017 ')
plt.xlabel('Year')
plt.ylabel('Total Radiative Forcing (W m^-2)')


plt.subplot(3,1,2)
plt.plot(co2ppm['Mean'])
plt.title('Average Annual Atmospheric CO2 in PPM 1959-2017')
plt.xlabel('Year')
plt.ylabel('CO2 in PPM')


plt.subplot(3,1,3)
#Where 'J-D' represents the average mean temperature anomolies for the whole year (from January to December)
plt.plot(temp['J-D'])
plt.title('Mean Annual Temperature Anomalies 1880-2018')
plt.xlabel('Year')
plt.ylabel('Mean Anomalies (C)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Observation</h2>
# <p>As we can see, all three measurements have a general upward trend over their respective time ranges. The range we will be focusing on will be the years 1908-2017 over which all of our measurements overlap. We wish to answer the question: is there corelation between the atmospheric carbon dioxide concentration and the annual mean temperature anomalies?</p>

# %%
#Plot Total RF to CO2 in PPM for the years 1980 to 2017
aggi_join_co2 = aggi.join(co2ppm)

aggi_join_temp = aggi.join(temp)

co2_join_temp = co2ppm.join(temp)

plt.figure(figsize = (10,10))

plt.subplot(2,2,1)
plt.scatter(x = aggi_join_co2['Mean'], y = aggi_join_co2['Total RF'])
plt.title('Atmospheric CO2 to Total Radiative Forcing')
plt.xlabel('Mean Annual Atmospheric CO2 (PPM)')
plt.ylabel('Total Radiative Forcing (W m^-2)')

plt.subplot(2,2,2)
plt.scatter(x = co2_join_temp['Mean'], y = co2_join_temp['J-D'])
plt.title('Atmospheric CO2 to Mean Annual Temperature Anomalies')
plt.xlabel('Mean Annual Atmospheric CO2 (PPM)')
plt.ylabel('Mean Annual Temperature Anomalies (C)')

plt.subplot(2,2,3)
plt.scatter(x = aggi_join_temp['Total RF'], y = aggi_join_temp['J-D'])
plt.title('Radiation Forcing to Mean Annual Temperature Deviations')
plt.xlabel('Radiation Forcing (W m^-2)')
plt.ylabel('Mean Annual Temperature Anomalies(C)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Analysis</h2>
# <p>Both the average annual atmospheric CO2 content and the total radiative forcing show a consistent upward trend in their respective time range. Plotting the mean anual CO2 atmospheric composition against the total radiative forcing shows an apparent linear correlation between the two. This is expected because total radiative forcing is calculated as a function of the concentration of greenhouse gasses in the atmosphere, in which carbon dioxide is the most prominent.</p>
# <p>Total radiative forcing encompasses calculated radiative forcing done by other prominent greenhouse gases and thus gives us a more encompassing look at the corelation between greenhouse gases and global temperatures. However, we have around 20 years more data when we look at the relationship between the mean annual temperature anomalies and the concentration of carbon dioxide in the atmosphere. We shall perform regression analysis on both samples, determine if they are corelated and if we can reject the null hypothesis which states there is no statistically significant corelation between these two measurements.</p>

# %%
plt.figure(figsize=(12,4))

def draw_line(m, b, xlim, resolution, clr = 'red'):
    x = np.linspace(xlim[0],xlim[1],resolution)
    y = m * x + b
    plt.plot(x, y, 'r--', color = clr)
    

#Relation between CO2 and mean temperature anomalies
m_1, b_1, r_value_1, p_value_1, std_err_1 = stats.linregress(x = co2_join_temp['Mean'], y = co2_join_temp['J-D'])

plt.subplot(1,2,1)

plt.scatter(x = co2_join_temp['Mean'], y = co2_join_temp['J-D'])
draw_line(m_1, b_1, plt.xlim(), 50)

plt.title('Atmospheric CO2 to Mean Annual Temperature Anomalies')
plt.xlabel('Mean Annual Atmospheric CO2 (PPM)\n\nR-Value: {}\nP-Value: {}'.format(r_value_1, p_value_1))
plt.ylabel('Mean Annual Temperature Anomalies (C)')



#Relation between calculated solar forcing and mean temperature anomalies
m_2, b_2, r_value_2, p_value_2, std_err_2 = stats.linregress(x = aggi_join_temp['Total RF'], y = aggi_join_temp['J-D'])

plt.subplot(1,2,2)

plt.scatter(x = aggi_join_temp['Total RF'], y = aggi_join_temp['J-D'])
draw_line(m_2, b_2, plt.xlim(), 50)

plt.title('Radiation Forcing to Mean Annual Temperature Deviations')
plt.xlabel('Radiation Forcing (W m^-2)\n\nR-Value: {}\nP-Value: {}'.format(r_value_2, p_value_2))
plt.ylabel('Mean Annual Temperature Anomalies(C)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <p>As we can see, with p-values of 2.3*10^-30 and 2.6*10^-14 respectively, we can safely reject the null hypothesis. And with r-values 0.94 and 0.89, we can describe the relationships bewtween these variables as strong and positive. And so we can say with almost absolute certainty that these measurements are corelated.</p>
#
# <h2>Predictive Analysis</h2>
# <p>The next question is making a prediction using our algorithm to make an educated prediction of 2019's mean annual temperature anomalies. To do this, we will perform our simple linear regression algorithm on two sections of data, the entire 1880-2018 data range and the range 1970-2018, where a visual glance at the data suggests a relatively recent upwards trend. First, the whole range:</p>

# %%
plt.figure(figsize = (10, 5))


#Finding the line of best fit for the whole series
m_1, b_1, r_value_1, p_value_1, std_err_1 = stats.linregress(x = temp.index, y = temp['J-D'])

plt.subplot(1,2,1)
plt.plot(temp['J-D'])
draw_line(m_1, b_1, plt.xlim(), 50, 'green')
plt.title('Mean Annual Temperature Anomalies 1880-2018')
plt.xlabel('Year\n\nY = {} * X + {}\nP-value:{}\nStandard Error: {}'.format(round(m_1,4), round(b_1,4), 
                                                                            p_value_1, std_err_1))
plt.ylabel('MATA (C)')

#Finding and plotting the line of best fit for 1970 and later
m_2, b_2, r_value_2, p_value_2, std_err_2 = stats.linregress(temp[temp.index >= 1970].index, 
                                                             temp[temp.index >= 1970]['J-D'])

plt.subplot(1,2,2)
plt.plot(temp[temp.index >= 1970].index, temp[temp.index >= 1970]['J-D'])
draw_line(m_2, b_2, plt.xlim(), 50, 'red')
plt.title('Mean Annual Temperature Anomalies 1970-2018')
plt.xlabel('Year\n\nY = {} * X + {}\nP-value:{}\nStandard Error: {}'.format(round(m_2,4), round(b_2,4), 
                                                                            p_value_2, std_err_2))
plt.ylabel('MATA (C)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <p>Interestingly, the standard error and the P-value for the whole range of 1880 to 2018 is smaller than the standard error for the range 1970-2018, even though by intuition the data from 1970-2018 appears more linear. Mathematically it makes sense because the standard error is inversely proportional to the square root of the number of samples, and as we have more samples between 1880-2018 as opposed to 1970-2018 we would expect this. Perhaps it would be better to model the data between the years 1880-2018 with exponential regression.</p>
# <p>Next, we must ask 'what is the standard deviation of the variance from the best fit line'? Answering this question will give us degrees of confidence to work with.</p>

# %%
#Simple linear function
def y_equals_lin(x, m, b):
    return m*x + b

#Create shortened dataframe to work with.
temp1970 = temp[temp.index >= 1970]

#Add a section for deviaton from linear best fit
temp1970['var_lin'] = temp1970['J-D']  - y_equals_lin(m_2, temp1970.index, b_2) #Produces warning even when I follow advice.

#Set Standard Deviation, maintaining convention that var_2 represents statistical measurement for data from 1970 to 2018
std_2 = np.std(temp1970['var_lin'])

#Show histogram of the deviations
plt.hist(temp1970['var_lin'], normed=True)
plt.title('Variance of Measurement from Best Fit Line')

#Plot mean variance and standard deviations
plt.axvline(x = np.mean(temp1970['var_lin']), color = 'green')
plt.axvline(x = np.mean(temp1970['var_lin']) + std_2, color = 'red')
plt.axvline(x = np.mean(temp1970['var_lin']) - std_2, color = 'red')

plt.xlabel('Variance (C)')
plt.show()
# Out:
# C:\Users\peter\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# <p>As we can see by the histogram of variance most of the data appears to be encompassed within two standard deviations from the mean. The question is: are there more data points within one standard deviation of the mean than there are between one and two? We can answer this question by counting how many are in this range.</p>

# %%
count_1std = len(temp1970[abs(temp1970['var_lin']) <= std_2])
count_2std = len(temp1970[abs(temp1970['var_lin']) <= 2 * std_2])
count_tot = len(temp1970.index)
print('Within one std: {}, Within two std: {}, total: {}'.format(count_1std, count_2std, count_tot))
print('Chance 1 std: {}%, Chance 2 std: {}%'.format(round((count_1std / count_tot) * 100, 2), 
                                                    round((count_2std / count_tot) * 100, 2)))
# Out:
# Within one std: 30, Within two std: 48, total: 49
# Chance 1 std: 61.22%, Chance 2 std: 97.96%

# %% [markdown]
# <p>Given the distribution of variance and an expression for the line of best fit, we can make a reasonable guess with a degree of confidence what the mean temperature anomalies will be in 2019.</p>

# %%
plt.figure(figsize = (12,10))
plt.plot(temp1970['J-D'])
draw_line(m_2, b_2, (1970, 2025), 50, 'purple')

#Draw year line, intersection line, std dev lines.
plt.axvline(x = 2019, color = 'green', linestyle = '--')

plt.axhline(y = y_equals_lin(m_2, 2019, b_2), color = 'red')

plt.axhline(y = y_equals_lin(m_2, 2019, b_2) + std_2, color = 'red', linestyle = '--')
plt.axhline(y = y_equals_lin(m_2, 2019, b_2) - std_2, color = 'red', linestyle = '--')

plt.axhline(y = y_equals_lin(m_2, 2019, b_2) + 2 * std_2, color = 'orange', linestyle = '--')
plt.axhline(y = y_equals_lin(m_2, 2019, b_2) - 2 * std_2, color = 'orange', linestyle = '--')

#Titles and Labels
plt.title('Mean Annual Temperature Anomalies 1970-2018')
plt.xlabel('Year')
plt.ylabel('MATA (C)')
plt.show()

print('For 2019:')
print('61% Chance: {} +/- {} degrees C'.format(round(y_equals_lin(m_2, 2019, b_2),4) , round(std_2, 4)))
print('97% Chance: {} +/- {} degrees C'.format(round(y_equals_lin(m_2, 2019, b_2),4) , round(2 * std_2, 4)))
# Out:
# For 2019:
# 61% Chance: 0.8531 +/- 0.094 degrees C
# 97% Chance: 0.8531 +/- 0.1881 degrees C

# %% [markdown]
# <h2>Proposed Further Study</h2>
# <p>I propose we use a machine learning algorithm to predict the CO2 concentrations and mean temperature anomalies. We can use similar algorithms to explore more nuances in the data when we look at shorter timespans (ie months), this would give us more data points to work with, as well as introduce more interesting features to explore, at the risk of introducing more noise in the data.</p>
